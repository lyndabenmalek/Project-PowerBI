# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns 
from ydata_profiling import ProfileRe
port
import numpy as np
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
import pypyodbc as podbc

conn2 = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=LAPTOP_LYNDA;"
                     "Database=DW_Finance;"
                     "Trusted_Connection=yes;")

# rynning the SQL query i need
df= pd.read_sql_query('''SELECT * FROM [dbo].[Suppliers_Cluster]''', conn2)

# Viz
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15004 entries, 0 to 15003
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Satisfaction Level         15004 non-null  float64
#  1   Last Evaluation            15004 non-null  float64
#  2   Number of Projects         14999 non-null  float64
#  3   Monthly Hours              15004 non-null  int64
#  4   Total Time at the Company  14999 non-null  float64
#  5   Work Accidents             15000 non-null  float64
#  6   Quit the Company           15004 non-null  int64
#  7   Promoted in Last 5 yrs     15004 non-null  int64
#  8   salary                     15004 non-null  object
#  9   Management                 15004 non-null  int64
#  10  Categorie Fournisseur      15004 non-null  object
# dtypes: float64(5), int64(4), object(2)
# memory usage: 1.3+ MB

# %%
# Import the classification module from pycaret
from pycaret.classification import *

# Set up the pycaret environment
setup(df, target='Quit the Company',normalize=True, session_id=100)
# Out:
# <style type="text/css">
# #T_75870_row10_col1, #T_75870_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_75870">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75870_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_75870_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75870_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75870_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_75870_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_75870_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75870_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_75870_row1_col1" class="data row1 col1" >Quit the Company</td>
#     </tr>
#     <tr>
#       <th id="T_75870_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2469e th {
#   text-align: left;
# }
# ...

# %%
model=create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_57a52_row10_col0, #T_57a52_row10_col1, #T_57a52_row10_col2, #T_57a52_row10_col3, #T_57a52_row10_col4, #T_57a52_row10_col5, #T_57a52_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_57a52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57a52_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_57a52_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_57a52_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_57a52_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_57a52_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_57a52_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_57a52_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
t_model= tune_model(model)
# Out:
# <style type="text/css">
# #T_6c3a8_row10_col0, #T_6c3a8_row10_col1, #T_6c3a8_row10_col2, #T_6c3a8_row10_col3, #T_6c3a8_row10_col4, #T_6c3a8_row10_col5, #T_6c3a8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6c3a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c3a8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6c3a8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6c3a8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6c3a8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6c3a8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6c3a8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6c3a8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(model, 'ClusterSuppliers')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Satisfaction Level',
#                                               'Last Evaluation',
#                                               'Number of Projects',
#                                               'Monthly Hours',
#                                               'Total Time at the Company',
#                                               'Work Accidents',
#                                               'Promoted in Last 5 yrs',
#                                               'Management'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
# ...

# %%
 #Extrayez le modèle scikit-learn sous-jacent
import joblib
# Chargez votre modèle PyCaret
pycaret_model = load_model("C:/Users/lynda/OneDrive/Desktop/BiPi/LesObjectifsML/ClusterSuppliers")
# Extract the trained model from the pipeline
sklearn_model = pycaret_model.steps[-1][1]

# Sauvegardez le modèle scikit-learn extrait
joblib.dump(sklearn_model, "C:/Users/lynda/OneDrive/Desktop/BiPi/LesObjectifsML/ClusterSuppliers_sklearn_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       2 import joblib
#       3 # Chargez votre modèle PyCaret
# ----> 4 pycaret_model = load_model("C:/Users/lynda/OneDrive/Desktop/BiPi/LesObjectifsML/ClusterSuppliers")
#       5 # Extract the trained model from the pipeline
#       6 sklearn_model = pycaret_model.steps[-1][1]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pycaret\classification\functional.py:2442, in load_model(model_name, platform, authentication, verbose)
#    2439 if experiment is None:
#    2440     experiment = _EXPERIMENT_CLASS()
# -> 2442 return experiment.load_model(
#    2443     model_name=model_name,
#    2444     platform=platform,
#    2445     authentication=authentication,
#    2446     verbose=verbose,
#    2447 )
#
# ...
